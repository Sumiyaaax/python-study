# %%
from bs4 import BeautifulSoup
import urllib.request as req

url = 'https://www.simplex.inc'
# url = 'https://note.com/sumiiyaaax/'
response = req.urlopen(url)

# %%
print(response)
# Out:
# <http.client.HTTPResponse object at 0x7fd869e89130>

# %%
parse_html = BeautifulSoup(response, 'html.parser')

# %%
parse_html
# Out:
# <!DOCTYPE html>
#
# <html lang="ja">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=0" id="viewport" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>シンプレクス株式会社 | Biz×TechでDXを支援</title>
# <meta content="max-image-preview:large" name="robots">
# <!-- All In One SEO Pack 3.7.1ob_start_detected [-1,-1] -->
# <meta content="シンプレクスは、DXを支援するテクノロジーパートナーとして、幅広い業界の課題に対し、戦略から設計、開発、運用保守まで、一気通貫かつ自社完結でのトータルソリューションを提供しています。" name="description">
# <script class="aioseop-schema" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.simplex.inc/#organization","url":"https://www.simplex.inc/","name":"シンプレクス株式会社","sameAs":[]},{"@type":"WebSite","@id":"https://www.simplex.inc/#website","url":"https://www.simplex.inc/","name":"シンプレクス株式会社","publisher":{"@id":"https://www.simplex.inc/#organization"},"potentialAction":{"@type":"SearchAction","target":"https://www.simplex.inc/?s={search_term_string}","query-input":"required name=search_term_string"}},{"@type":"WebPage","@id":"https://www.simplex.inc#webpage","url":"https://www.simplex.inc","inLanguage":"ja","name":"シンプレクス株式会社","isPartOf":{"@id":"https://www.simplex.inc/#website"},"breadcrumb":{"@id":"https://www.simplex.inc#breadcrumblist"},"description":"シンプレクスは、DXを支援するテクノロジーパートナーとして、幅広い業界の課題に対し、戦略から設計、開発、運用保守まで、一気通貫かつ自社完結でのトータルソリューションを提供しています。","about":{"@id":"https://www.simplex.inc/#organization"}},{"@type":"BreadcrumbList","@id":"https://www.simplex.inc#breadcrumblist","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"WebPage","@id":"https://www.simplex.inc/","url":"https://www.simplex.inc/","name":"シンプレクス株式会社"}}]}]}</script>
# <link href="https://www.simplex.inc/" rel="canonical"/>
# <meta content="website" property="og:type">
# <meta content="シンプレクス株式会社 | Biz×TechでDXを支援" property="og:title">
# <meta content="シンプレクスは、DXを支援するテクノロジーパートナーとして、幅広い業界の課題に対し、戦略から設計、開発、運用保守まで、一気通貫かつ自社完結でのトータルソリューションを提供しています。" property="og:description"/>
# <meta content="https://www.simplex.inc/" property="og:url"/>
# <meta content="シンプレクス株式会社" property="og:site_name"/>
# <meta content="https://www.simplex.inc/ogp.png" property="og:image"/>
# <meta content="https://www.simplex.inc/ogp.png" property="og:image:secure_url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="シンプレクス株式会社 | Biz×TechでDXを支援" name="twitter:title"/>
# <meta content="シンプレクスは、DXを支援するテクノロジーパートナーとして、幅広い業界の課題に対し、戦略から設計、開発、運用保守まで、一気通貫かつ自社完結でのトータルソリューションを提供しています。" name="twitter:description"/>
# <meta content="https://www.simplex.inc/ogp.png" name="twitter:image"/>
# <!-- All In One SEO Pack -->
# <link href="/favicon.ico" rel="icon"/>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//cdnjs.cloudflare.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//fonts.gstatic.com" rel="dns-prefetch"/>
# <link href="//cdn.jsdelivr.net" rel="dns-prefetch"/>
# <link href="//cdnjs.cloudflare.com/ajax/libs/normalize/8.0.1/normalize.min.css" rel="stylesheet"/>
# <link href="//fonts.googleapis.com/css2?family=Noto+Sans+JP:wght@400;500;700&amp;display=swap&amp;subset=japanese" rel="stylesheet"/>
# <link href="//fonts.googleapis.com/css2?family=Heebo:wght@400;700&amp;display=swap" rel="stylesheet"/>
# <link href="//cdn.jsdelivr.net/npm/yakuhanjp@3.4.1/dist/css/yakuhanjp.min.css" rel="stylesheet"/>
# <link href="//cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick.min.css" rel="stylesheet"/>
# <link href="/assets/css/main.css" rel="stylesheet"/>
# <link href="/assets/css/parts.css" rel="stylesheet"/>
# <link href="/assets/css/module.css" rel="stylesheet"/>
# <link href="/assets/css/home.css" rel="stylesheet"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-L9C84QZWYZ"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'G-L9C84QZWYZ');
#   gtag('config', 'UA-46476456-2');
# </script>
# </meta></meta></meta></meta></head>
# <body class="body--transparent">
# <!-- wrapper -->
# <div class="wrapper">
# <!-- loading -->
# <div class="loading js-loading">
# <div class="loading__mask"></div>
# <div class="loading__progress">
# <div class="loading__icons">
# <div class="loading__icon"></div>
# <div class="loading__icon"></div>
# <div class="loading__icon"></div>
# <div class="loading__icon"></div>
# </div>
# </div>
# </div>
# <!-- /loading -->
# <!-- header -->
# <header class="header js-header">
# <div class="header__outer">
# <div class="header__inner">
# <div class="header__logo">
# <a href="/">
# 								シンプレクス株式会社
# 							</a>
# </div>
# <div class="header__tools">
# <div class="header__language">
# <a class="underlink" href="https://www.simplex.ne.jp/en/">
# 									English
# 								</a>
# </div>
# <div class="header__search js-searchopen">
# <div class="menu menu--close">
# <span class="menu__icon">
# <span class="menu__bar"></span>
# </span>
# <span class="menu__label">
# 										Close
# 									</span>
# </div>
# </div>
# <div class="header__menu js-menuopen">
# <div class="menu menu--open">
# <span class="menu__icon">
# <span class="menu__bar"></span>
# </span>
# <span class="menu__label">
# 										Close
# 									</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <!-- /header -->
# <!-- nav -->
# <nav class="nav js-nav">
# <div class="nav__frame">
# <div class="nav__outer">
# <div class="nav__inner">
# <div class="nav__items">
# <div class="nav__item nav__item--reason">
# <div class="nav__label">
# <a class="nav__labeltext" href="/reason/">
# 											選ばれる理由
# 											<span class="nav__arrow"></span>
# </a>
# </div>
# </div>
# <div class="nav__item nav__item--service js-submenu">
# <div class="nav__label js-accordion js-accordion-sp">
# <span class="nav__labeltext">
# 											サービス
# 											<span class="nav__door"></span>
# </span>
# </div>
# <div class="nav__content">
# <div class="nav__base">
# <div class="nav__subnav">
# <div class="nav__subnavinner">
# <ul class="nav__lists">
# <li class="nav__list">
# <a class="linebutton" href="/service/finance/">
# <span class="linebutton__label">
# 																	金融サービス開発
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/service/ui-ux-design/">
# <span class="linebutton__label">
# 																	UI/UXデザイン
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/service/cloud/">
# <span class="linebutton__label">
# 																	クラウド
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/service/consulting/">
# <span class="linebutton__label">
# 																	コンサルティング
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/service/ai/">
# <span class="linebutton__label">
# 																	AI（人工知能）
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/service/blockchain/">
# <span class="linebutton__label">
# 																	ブロックチェーン
# 																</span>
# </a>
# </li>
# </ul>
# <ul class="nav__banners pc">
# <li class="nav__banner">
# <a class="button" href="/solution/">
# <span class="button__label">
# 																	 ソリューション一覧
# 																</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="nav__item nav__item--industries js-submenu">
# <div class="nav__label js-accordion js-accordion-sp">
# <span class="nav__labeltext">
# 											業界
# 											<span class="nav__door"></span>
# </span>
# </div>
# <div class="nav__content">
# <div class="nav__base">
# <div class="nav__subnav">
# <div class="nav__subnavinner">
# <ul class="nav__lists">
# <li class="nav__list">
# <a class="linebutton" href="/industries/bank/">
# <span class="linebutton__label">
# 																	銀行
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/industries/securities_wholesale/">
# <span class="linebutton__label">
# 																	証券
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/industries/insurance/">
# <span class="linebutton__label">
# 																	保険
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/industries/fx/">
# <span class="linebutton__label">
# 																	FX
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/industries/cryptocurrency/">
# <span class="linebutton__label">
# 																	暗号資産
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/industries/construction/">
# <span class="linebutton__label">
# 																	建設
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/industries/public/">
# <span class="linebutton__label">
# 																	公共
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/industries/manufacture/">
# <span class="linebutton__label">
# 																	製造
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/industries/retail/">
# <span class="linebutton__label">
# 																	小売・流通
# 																</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="nav__item nav__item--solution sp">
# <div class="nav__label">
# <a class="nav__labeltext" href="/solution/">
# 											ソリューション
# 											<span class="nav__arrow"></span>
# </a>
# </div>
# </div>
# <div class="nav__item nav__item--casestudy sp">
# <div class="nav__label">
# <a class="nav__labeltext" href="/casestudy/">
# 											事例紹介
# 											<span class="nav__arrow"></span>
# </a>
# </div>
# </div>
# <!--
# 								<div class="nav__item nav__item--insight sp">
# 									<div class="nav__label">
# 										<a href="/search/" class="nav__labeltext">
# 											Simplex Insight
# 											<span class="nav__arrow"></span>
# 										</a>
# 									</div>
# 								</div>
# 								-->
# <div class="nav__item nav__item--company">
# <div class="nav__label js-accordion js-accordion-sp">
# <a class="nav__labeltext" href="/company/">
# 											企業情報
# 											<span class="nav__door"></span>
# </a>
# </div>
# <div class="nav__content">
# <div class="nav__base">
# <div class="nav__subnav">
# <div class="nav__subnavinner">
# <ul class="nav__lists">
# <li class="nav__list">
# <a class="linebutton" href="/company/message/">
# <span class="linebutton__label">
# 																	トップメッセージ
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/company/philosophy/">
# <span class="linebutton__label">
# 																	経営理念
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/company/about/">
# <span class="linebutton__label">
# 																	会社概要
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/company/history/">
# <span class="linebutton__label">
# 																	沿革
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/company/executives/">
# <span class="linebutton__label">
# 																	経営メンバー
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="/company/client/">
# <span class="linebutton__label">
# 																	主要取引先
# 																</span>
# </a>
# </li>
# <li class="nav__list">
# <a class="linebutton" href="https://www.simplex.holdings/company/finance/" target="_blank">
# <span class="linebutton__label">
# 																	業績・財務情報
# 																</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="nav__item nav__item--news">
# <div class="nav__label">
# <a class="nav__labeltext" href="/news/">
# 											ニュース
# 											<span class="nav__arrow"></span>
# </a>
# </div>
# </div>
# <div class="nav__item nav__item--recruit">
# <div class="nav__label">
# <a class="nav__labeltext" href="https://recruit-simplex.jp/" rel="noopener" target="_blank">
# 											採用情報
# 											<span class="nav__arrow"></span>
# </a>
# </div>
# </div>
# <div class="nav__item nav__item--contact pc">
# <div class="nav__label">
# <a class="nav__labeltext" href="/contact/">
# 											お問い合わせ
# 											<span class="nav__arrow"></span>
# </a>
# </div>
# </div>
# </div>
# <ul class="nav__sidelinks sp">
# <li class="nav__sidelink nav__sidelink--contact">
# <a href="/contact/">
# 										お問い合わせ
# 									</a>
# </li>
# <li class="nav__sidelink nav__sidelink--downloads">
# <a href="/downloads/">
# 										資料ダウンロード
# 									</a>
# </li>
# <li class="nav__sidelink nav__sidelink--en">
# <a href="https://www.simplex.ne.jp/en/">
# 										English
# 									</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </nav>
# <!-- /nav -->
# <!-- tagsearch -->
# <div class="tagsearch js-tagsearch">
# <div class="tagsearch__frame">
# <div class="tagsearch__outer">
# <div class="tagsearch__inner">
# <form action="javascript:;" id="frmSearchGlobal">
# <div class="tagsearch__title">
# 									タグ検索
# 								</div>
# <div class="tagsearch__columns">
# <div class="tagsearch__column">
# <div class="searchmenu">
# <div class="searchmenu__label">
# 												キーワード
# 											</div>
# <ul class="searchmenu__tag">
# <li>
# <input id="keyword_global4" name="keyword[]" type="checkbox" value="4"/><label for="keyword_global4">コンサルティング</label>
# </li>
# <li>
# <input id="keyword_global9" name="keyword[]" type="checkbox" value="9"/><label for="keyword_global9">金融サービス開発</label>
# </li>
# <li>
# <input id="keyword_global8" name="keyword[]" type="checkbox" value="8"/><label for="keyword_global8">UI/UXデザイン</label>
# </li>
# <li>
# <input id="keyword_global6" name="keyword[]" type="checkbox" value="6"/><label for="keyword_global6">クラウド</label>
# </li>
# <li>
# <input id="keyword_global5" name="keyword[]" type="checkbox" value="5"/><label for="keyword_global5">AI（人工知能）</label>
# </li>
# <li>
# <input id="keyword_global7" name="keyword[]" type="checkbox" value="7"/><label for="keyword_global7">ブロックチェーン</label>
# </li>
# <li>
# <input id="keyword_global32" name="keyword[]" type="checkbox" value="32"/><label for="keyword_global32">STO</label>
# </li>
# <li>
# <input id="keyword_global13" name="keyword[]" type="checkbox" value="13"/><label for="keyword_global13">CFD</label>
# </li>
# <li>
# <input id="keyword_global15" name="keyword[]" type="checkbox" value="15"/><label for="keyword_global15">RPA</label>
# </li>
# <li>
# <input id="keyword_global10" name="keyword[]" type="checkbox" value="10"/><label for="keyword_global10">マイクロサービス</label>
# </li>
# <li>
# <input id="keyword_global30" name="keyword[]" type="checkbox" value="30"/><label for="keyword_global30">イベント・セミナー</label>
# </li>
# <li>
# <input id="keyword_global31" name="keyword[]" type="checkbox" value="31"/><label for="keyword_global31">メディア掲載</label>
# </li>
# <li>
# <input id="keyword_global29" name="keyword[]" type="checkbox" value="29"/><label for="keyword_global29">アワード</label>
# </li>
# </ul>
# </div>
# </div>
# <div class="tagsearch__column">
# <div class="searchmenu">
# <div class="searchmenu__label">
# 												業界
# 											</div>
# <ul class="searchmenu__tag">
# <li>
# <input id="industries_global16" name="industries[]" type="checkbox" value="16"/><label for="industries_global16">銀行</label>
# </li>
# <li>
# <input id="industries_global17" name="industries[]" type="checkbox" value="17"/><label for="industries_global17">証券</label>
# </li>
# <li>
# <input id="industries_global20" name="industries[]" type="checkbox" value="20"/><label for="industries_global20">保険</label>
# </li>
# <li>
# <input id="industries_global18" name="industries[]" type="checkbox" value="18"/><label for="industries_global18">FX</label>
# </li>
# <li>
# <input id="industries_global19" name="industries[]" type="checkbox" value="19"/><label for="industries_global19">暗号資産</label>
# </li>
# <li>
# <input id="industries_global21" name="industries[]" type="checkbox" value="21"/><label for="industries_global21">建設</label>
# </li>
# <li>
# <input id="industries_global22" name="industries[]" type="checkbox" value="22"/><label for="industries_global22">公共</label>
# </li>
# <li>
# <input id="industries_global23" name="industries[]" type="checkbox" value="23"/><label for="industries_global23">製造</label>
# </li>
# <li>
# <input id="industries_global24" name="industries[]" type="checkbox" value="24"/><label for="industries_global24">小売・流通</label>
# </li>
# </ul>
# </div>
# </div>
# <div class="tagsearch__column">
# <div class="searchmenu">
# <div class="searchmenu__label">
# 												課題・目的
# 											</div>
# <ul class="searchmenu__tag">
# <li>
# <input id="purpose_global34" name="purpose[]" type="checkbox" value="34"/><label for="purpose_global34">リモートワーク監視</label>
# </li>
# <li>
# <input id="purpose_global35" name="purpose[]" type="checkbox" value="35"/><label for="purpose_global35">データ活用</label>
# </li>
# <li>
# <input id="purpose_global33" name="purpose[]" type="checkbox" value="33"/><label for="purpose_global33">個人資産運用</label>
# </li>
# <li>
# <input id="purpose_global28" name="purpose[]" type="checkbox" value="28"/><label for="purpose_global28">リスク管理</label>
# </li>
# <li>
# <input id="purpose_global25" name="purpose[]" type="checkbox" value="25"/><label for="purpose_global25">規制対応</label>
# </li>
# <li>
# <input id="purpose_global26" name="purpose[]" type="checkbox" value="26"/><label for="purpose_global26">ペーパーレス化</label>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="tagsearch__contents">
# <div class="searchmenu">
# <div class="searchmenu__label searchmenu__label--noborder">
# 											コンテンツ
# 										</div>
# <ul class="searchmenu__checkbox">
# <li>
# <input id="contents_global0" name="contents[]" type="checkbox" value="solution"/><label for="contents_global0">ソリューション</label>
# </li>
# <li>
# <input id="contents_global1" name="contents[]" type="checkbox" value="casestudy"/><label for="contents_global1">事例</label>
# </li>
# <!--
# 											<li>
# 												<input type="checkbox" name="contents[]" id="contents_global2" value="insight"><label for="contents_global2">Simplex Insight</label>
# 											</li>
# 											-->
# <li>
# <input id="contents_global3" name="contents[]" type="checkbox" value="news"/><label for="contents_global3">ニュース</label>
# </li>
# </ul>
# </div>
# </div>
# <div class="tagsearch__button">
# <button class="button button--search btnSearchSubmit" name="Global" type="button">
# <span class="button__label">
# 											絞り込む
# 										</span>
# </button>
# <button class="button button--reset btnSearchReset" name="Global" type="button">
# <span class="button__label">
# 											リセット
# 										</span>
# </button>
# </div>
# <div class="tagsearch__close">
# <div class="closebutton">
# <div class="closebutton__icon">
# <img alt="" height="42" src="/assets/img/common/tagsearch_close.svg" width="42"/>
# </div>
# <div class="closebutton__label">
# 											Close
# 										</div>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <!-- /tagsearch -->
# <!-- main -->
# <main class="main">
# <!-- intro -->
# <div class="intro js-intro">
# <div class="intro__outer">
# <div class="intro__inner">
# <div class="intro__header">
# <h1 class="intro__title">
# <span class="intro__one">
# <i>B</i><i>i</i><i>z</i>
# </span>
# <span class="intro__multi"></span>
# <span class="intro__two">
# <i>T</i><i>e</i><i>c</i><i>h</i>
# </span>
# </h1>
# <p class="intro__copy">
# <span class="intro__copylabel">
# <span>
# 											DXに必要なのは、ハイブリッドなパートナー
# 										</span>
# </span>
# </p>
# </div>
# </div>
# </div>
# <div class="intro__image">
# <span></span>
# </div>
# <div class="scroll">
# <div class="scroll__inner">
# <div class="scroll__label">
# 								Scroll
# 							</div>
# <div class="scroll__bar"></div>
# </div>
# </div>
# </div>
# <!-- /intro -->
# <!-- weare -->
# <section class="content weare" id="weare">
# <div class="content__outer">
# <div class="content__inner">
# <div class="weare__content">
# <div class="title">
# <div class="title__label">
# 										Who We Are
# 									</div>
# <h2 class="title__summary">
# <span class="slidein">
# <span class="slidein__label">
# 												ビジネスとテクノロジーに精通したプロフェッショナル集団
# 											</span>
# </span>
# </h2>
# </div>
# <div class="weare__textline">
# <p class="textline">
# 										シンプレクスがビジネスを成功に導く真のテクノロジーパートナーである理由。それは、戦略から設計、開発、運用保守のすべてに責任をもち、一気通貫でソリューションを提供するため。ビジネスとテクノロジーに精通したプロフェッショナルがワンチームとなり、各々がプレイヤーとして機能するSimplex Wayが、DXを志向するお客様から支持されています。
# 									</p>
# </div>
# <div class="weare__button">
# <span class="slidein">
# <span class="slidein__label">
# <a class="button" href="/reason/">
# <span class="button__label">
# 													シンプレクスが選ばれる理由
# 												</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- /weare -->
# <!-- wedo -->
# <section class="content wedo">
# <div class="content__outer">
# <div class="content__inner wedo__inner">
# <div class="title">
# <div class="title__label">
# 									What We Do
# 								</div>
# <h2 class="title__summary">
# <span class="slidein">
# <span class="slidein__label">
# 											豊富なノウハウにより、確かな付加価値を提供
# 										</span>
# </span>
# </h2>
# </div>
# <div class="wedo__textline">
# <p class="textline">
# 									金融機関のコア業務を支えるミッションクリティカルなシステム構築や、新しいユーザー体験をもたらす金融サービス開発で培った豊富なノウハウ。<br class="pc"/>シンプレクスが得意とする、ビジネス戦略立案力と先端テクノロジーの高度な実装力が、あらゆる業界のDX最前線で求められています。
# 								</p>
# </div>
# <!-- panelbox -->
# <div class="panelbox">
# <div class="panelbox__items">
# <div class="panelbox__item">
# <div class="panel">
# <a href="/capability/finance/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															金融サービス開発
# 														</p>
# <p class="panel__label">
# 															Financial Services Development
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_finance.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													サービスデザインから業務設計、システム開発まで、迅速な金融サービスの立ち上げを支援します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>
# </div>
# </div>
# <div class="panelbox__item">
# <div class="panel">
# <a href="/capability/ui-ux-design/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															UI/UXデザイン
# 														</p>
# <p class="panel__label">
# 															UI/UX Design
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_uiuxdesign.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													ビジネスを深く理解したUI/UXのエキスパートチームが、ユーザー体験を重視したプロダクト開発を支援します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>
# </div>
# </div>
# <div class="panelbox__item">
# <div class="panel">
# <a href="/capability/cloud/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															クラウド
# 														</p>
# <p class="panel__label">
# 															Cloud
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_cloud.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													先進事例からしか得られない揺るぎない知見を活かし、ビジネス戦略に則したクラウド導入を支援します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>
# </div>
# </div>
# <div class="panelbox__item">
# <div class="panel">
# <a href="/capability/consulting/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															コンサルティング
# 														</p>
# <p class="panel__label">
# 															Consulting
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_consulting.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													最先端テクノロジーに立脚した戦略立案と実行支援により、あらゆる業界のDX推進を支援します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>
# </div>
# </div>
# <div class="panelbox__item">
# <div class="panel">
# <a href="/capability/ai/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															AI（人工知能）
# 														</p>
# <p class="panel__label">
# 															Artificial Intelligence
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_ai.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													戦略策定からビジネス実装まで、あらゆるニーズに即戦力として応えるAIソリューションを提供します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>
# </div>
# </div>
# <div class="panelbox__item">
# <div class="panel">
# <a href="/capability/blockchain/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															ブロックチェーン
# 														</p>
# <p class="panel__label">
# 															Blockchain
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_blockchain.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													金融領域で培ったブロックチェーン技術と実績をもとに、新たなビジネスをお客様と共創します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- /panelbox -->
# </div>
# </div>
# </section>
# <!-- /wedo -->
# <!-- topbusiness -->
# <section class="content topbusiness">
# <div class="content__outer">
# <div class="content__inner topbusiness__inner">
# <div class="topbusiness__content">
# <div class="title">
# <div class="title__label pc">
# 										Business Domain
# 									</div>
# <div class="title__label sp">
# <span>Business</span><br/>
# <span>Domain</span>
# </div>
# <h2 class="title__summary">
# <span class="slidein">
# <span class="slidein__label">
# 												お客様の変革をともに考え、創造する
# 											</span>
# </span>
# </h2>
# </div>
# <div class="topbusiness__textline">
# <p class="textline">
# 										公的機関や金融機関、各業界をリードする企業のDX推進を支援しています。
# 									</p>
# </div>
# <ul class="topbusiness__linebutton">
# <li>
# <a class="linebutton" href="/industries/bank/">
# <span class="linebutton__label">
# 												銀行
# 											</span>
# </a>
# </li>
# <li>
# <a class="linebutton" href="/industries/construction/">
# <span class="linebutton__label">
# 											建設
# 											</span>
# </a>
# </li>
# <li>
# <a class="linebutton" href="/industries/securities_wholesale/">
# <span class="linebutton__label">
# 												証券
# 											</span>
# </a>
# </li>
# <li>
# <a class="linebutton" href="/industries/public/">
# <span class="linebutton__label">
# 												公共
# 											</span>
# </a>
# </li>
# <li>
# <a class="linebutton" href="/industries/insurance/">
# <span class="linebutton__label">
# 												保険
# 											</span>
# </a>
# </li>
# <li>
# <a class="linebutton" href="/industries/manufacture/">
# <span class="linebutton__label">
# 												製造
# 											</span>
# </a>
# </li>
# <li>
# <a class="linebutton" href="/industries/fx/">
# <span class="linebutton__label">
# 												FX
# 											</span>
# </a>
# </li>
# <li>
# <a class="linebutton" href="/industries/retail/">
# <span class="linebutton__label">
# 												小売・流通
# 											</span>
# </a>
# </li>
# <li>
# <a class="linebutton" href="/industries/cryptocurrency/">
# <span class="linebutton__label">
# 												暗号資産
# 											</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="topbusiness__image">
# <span class="js-parallax"></span>
# </div>
# </section>
# <!-- /topbusiness -->
# <!-- topnews -->
# <section class="content topnews">
# <div class="content__outer">
# <div class="content__inner topnews__inner">
# <div class="title">
# <div class="title__label">
# 									News
# 								</div>
# <h2 class="title__summary">
# <span class="slidein">
# <span class="slidein__label">
# 											最新情報
# 										</span>
# </span>
# </h2>
# </div>
# <div class="topnews__newsindex">
# <div class="newsindex">
# <div class="newsindex__header">
# <time class="newsindex__date" datetime="2021-05-31">
# <span class="newsindex__day">
# 															31
# 														</span>
# <span class="newsindex__month">
# 															May.<br/>
# 															2021
# 														</span>
# </time>
# <div class="categorylabel">
# 														お知らせ
# 													</div>
# </div>
# <div class="newsindex__subject">
# <a class="linker" href="https://www.simplex.inc/news/2021/971/" target="_self">
# 														コーポレートサイトリニューアルのお知らせ
# 													</a>
# </div>
# </div>
# <div class="newsindex">
# <div class="newsindex__header">
# <time class="newsindex__date" datetime="2021-05-26">
# <span class="newsindex__day">
# 															26
# 														</span>
# <span class="newsindex__month">
# 															May.<br/>
# 															2021
# 														</span>
# </time>
# <div class="categorylabel">
# 														ニュースリリース
# 													</div>
# </div>
# <div class="newsindex__subject">
# <a class="linker" href="https://www.simplex.inc/news/2021/969/" target="_self">
# 														松井証券の「ネットストック・ハイスピード」のサーバ基盤をAWS上に構築
# 													</a>
# </div>
# </div>
# <div class="newsindex">
# <div class="newsindex__header">
# <time class="newsindex__date" datetime="2021-05-18">
# <span class="newsindex__day">
# 															18
# 														</span>
# <span class="newsindex__month">
# 															May.<br/>
# 															2021
# 														</span>
# </time>
# <div class="categorylabel">
# 														お知らせ
# 													</div>
# </div>
# <div class="newsindex__subject">
# <a class="linker" href="https://www.simplex.inc/news/2021/890/" target="_self">
# 														AWSの「2021 APN AWS Top Engineers」に当社プリンシパルが選出
# 													</a>
# </div>
# </div>
# <div class="newsindex">
# <div class="newsindex__header">
# <time class="newsindex__date" datetime="2021-05-17">
# <span class="newsindex__day">
# 															17
# 														</span>
# <span class="newsindex__month">
# 															May.<br/>
# 															2021
# 														</span>
# </time>
# <div class="categorylabel">
# 														ニュースリリース
# 													</div>
# </div>
# <div class="newsindex__subject">
# <a class="linker" href="https://www.simplex.inc/news/2021/837/" target="_self">
# 														シンプレクス、新スマホアプリ「松井証券 株アプリ」を構築
# 													</a>
# </div>
# </div>
# <div class="newsindex">
# <div class="newsindex__header">
# <time class="newsindex__date" datetime="2021-04-01">
# <span class="newsindex__day">
# 															01
# 														</span>
# <span class="newsindex__month">
# 															Apr.<br/>
# 															2021
# 														</span>
# </time>
# <div class="categorylabel">
# 														お知らせ
# 													</div>
# </div>
# <div class="newsindex__subject">
# <a class="linker" href="https://www.simplex.inc/news/2021/557/" target="_self">
# 														DXを支援する「総合コンサルティングファーム」を創設［シンプレクスHD］
# 													</a>
# </div>
# </div>
# </div>
# <div class="topnews__button">
# <span class="slidein">
# <span class="slidein__label">
# <a class="button" href="/news/">
# <span class="button__label">
# 												ニュース一覧
# 											</span>
# </a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </section>
# <!-- /topnews -->
# </main>
# <!-- /main -->
# <!-- contactbox -->
# <div class="contactbox">
# <div class="contactbox__outer">
# <div class="contactbox__inner">
# <div class="contactbox__columns">
# <div class="contactbox__column">
# <div class="title title--white">
# <div class="title__label">
# 										Contact Us
# 									</div>
# <p class="title__summary">
# <span class="slidein__label">
# 											お問い合わせ
# 										</span>
# </p>
# </div>
# </div>
# <div class="contactbox__column">
# <div class="contactbox__button">
# <a class="button" href="/contact/">
# <span class="button__label">
# 											お問い合わせ
# 										</span>
# </a>
# </div>
# <div class="contactbox__button">
# <a class="button" href="/downloads/">
# <span class="button__label">
# 											資料ダウンロード
# 										</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- /contactbox -->
# <!-- compactfooter -->
# <div class="compactfooter">
# <div class="compactfooter__logo">
# <a href="/">
# 						シンプレクス株式会社
# 					</a>
# </div>
# <div class="compactfooter__copyright">
# 					Copyright © Simplex Inc.
# 				</div>
# </div>
# <!-- /compactfooter -->
# <!-- footer -->
# <footer class="footer">
# <div class="footer__outer">
# <div class="footer__inner">
# <!-- sitemap -->
# <div class="sitemap">
# <div class="sitemap__main">
# <div class="sitemap__logo">
# <a href="/">
# 										シンプレクス株式会社
# 									</a>
# </div>
# <p class="sitemap__name">
# 									シンプレクス株式会社
# 								</p>
# <p class="sitemap__address">
# 									〒105-6319<br/>
# 									東京都港区虎ノ門1-23-1<br/>
# 									虎ノ門ヒルズ森タワー19階
# 								</p>
# </div>
# <div class="sitemap__side">
# <div class="sitemap__columns">
# <div class="sitemap__column">
# <div class="sitemap__menu">
# <span class="sitemap__label">
# 												サービス
# 											</span>
# </div>
# <ul class="sitemap__submenu">
# <li>
# <a href="/service/finance/">
# 													金融サービス開発
# 												</a>
# </li>
# <li>
# <a href="/service/ui-ux-design/">
# 													UI/UXデザイン
# 												</a>
# </li>
# <li>
# <a href="/service/cloud/">
# 													クラウド
# 												</a>
# </li>
# <li>
# <a href="/service/consulting/">
# 													コンサルティング
# 												</a>
# </li>
# <li>
# <a href="/service/ai/">
# 													AI（人工知能）
# 												</a>
# </li>
# <li>
# <a href="/service/blockchain/">
# 													ブロックチェーン
# 												</a>
# </li>
# </ul>
# </div>
# <div class="sitemap__column">
# <div class="sitemap__menu">
# <span class="sitemap__label">
# 												業界
# 											</span>
# </div>
# <ul class="sitemap__submenu">
# <li>
# <a href="/industries/bank/">
# 													銀行
# 												</a>
# </li>
# <li>
# <a href="/industries/securities_wholesale/">
# 													証券
# 												</a>
# </li>
# <li>
# <a href="/industries/insurance/">
# 													保険
# 												</a>
# </li>
# <li>
# <a href="/industries/fx/">
# 													FX
# 												</a>
# </li>
# <li>
# <a href="/industries/cryptocurrency/">
# 													暗号資産
# 												</a>
# </li>
# <li>
# <a href="/industries/construction/">
# 													建設
# 												</a>
# </li>
# <li>
# <a href="/industries/public/">
# 													公共
# 												</a>
# </li>
# <li>
# <a href="/industries/manufacture/">
# 													製造
# 												</a>
# </li>
# <li>
# <a href="/industries/retail/">
# 													小売・流通
# 												</a>
# </li>
# </ul>
# </div>
# <div class="sitemap__column">
# <div class="sitemap__menu">
# <a class="sitemap__label" href="/reason/">
# 												選ばれる理由
# 											</a>
# </div>
# <div class="sitemap__menu">
# <a class="sitemap__label" href="/solution/">
# 												ソリューション一覧
# 											</a>
# </div>
# <div class="sitemap__menu">
# <a class="sitemap__label" href="/casestudy/">
# 												事例紹介
# 											</a>
# </div>
# <!--
# 										<div class="sitemap__menu">
# 											<a href="/search/" class="sitemap__label">
# 												Simplex Insight
# 											</a>
# 										</div>
# 										-->
# </div>
# <div class="sitemap__column">
# <div class="sitemap__menu">
# <a class="sitemap__label" href="/company/">
# 												企業情報
# 											</a>
# </div>
# <ul class="sitemap__submenu">
# <li>
# <a href="/company/message/">
# 													トップメッセージ
# 												</a>
# </li>
# <li>
# <a href="/company/philosophy/">
# 													経営理念
# 												</a>
# </li>
# <li>
# <a href="/company/about/">
# 													会社概要
# 												</a>
# </li>
# <li>
# <a href="/company/history/">
# 													沿革
# 												</a>
# </li>
# <li>
# <a href="/company/executives/">
# 													経営メンバー
# 												</a>
# </li>
# <li>
# <a href="/company/client/">
# 													主要取引先
# 												</a>
# </li>
# <li>
# <a href="https://www.simplex.holdings/company/finance/" target="_blank">
# 													業績・財務情報
# 												</a>
# </li>
# </ul>
# <div class="sitemap__menu">
# <a class="sitemap__label" href="/news/">
# 												ニュース
# 											</a>
# </div>
# <div class="sitemap__menu">
# <a class="sitemap__label" href="https://recruit-simplex.jp/" rel="noopener" target="_blank">
# 												採用情報
# 											</a>
# </div>
# <div class="sitemap__menu">
# <a class="sitemap__label" href="/downloads/">
# 												資料ダウンロード
# 											</a>
# </div>
# <div class="sitemap__menu">
# <a class="sitemap__label" href="/contact/">
# 												お問い合わせ
# 											</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- /sitemap -->
# <!-- siteinfo -->
# <div class="siteinfo">
# <ul class="siteinfo__link">
# <li>
# <a href="/term/">
# 										サイトポリシー
# 									</a>
# </li>
# <li>
# <a href="/security/">
# 										情報セキュリティ基本方針
# 									</a>
# </li>
# <li>
# <a href="/privacy/">
# 										個人情報保護方針
# 									</a>
# </li>
# <li>
# <a href="/sitemap/">
# 										サイトマップ
# 									</a>
# </li>
# <li>
# <a href="https://www.simplex.holdings/notification/" target="_blank">
# 										電子公告
# 									</a>
# </li>
# </ul>
# <p class="siteinfo__copy">
# 								Copyright © Simplex Inc.
# 							</p>
# </div>
# <!-- /siteinfo -->
# </div>
# </div>
# </footer>
# <!-- /footer -->
# <!-- pageup -->
# <div class="pageup js-pageup">
# <span class="pageup__label">
# 					Page Top
# 				</span>
# </div>
# <!-- /pageup -->
# <!-- contentmask -->
# <div class="contentmask js-contentmask"></div>
# <!-- /contentmask -->
# </div>
# <!-- /wrapper -->
# <script src="//ajax.googleapis.com/ajax/libs/jquery/3.6.0/jquery.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick.min.js"></script>
# <script src="/assets/js/main.js"></script>
# <script>
# 						intro.ready();
# 					</script>
# <form action="/search/" id="frmSearchSubmitGlobal" mthod="get"></form>
# <form action="/search/" id="frmSearchSubmitSide" mthod="get"></form>
# <script>
# 			$(function(){
# 				$(".btnSearchReset").on("click", function(){
# 					formSearchReset($(this).attr("name"));
# 				});
# 				$(".btnSearchSubmit").on("click", function(){
# 					formSearchSubmit($(this).attr("name"));
# 				});
#
#
# 				function formSearchReset(target) {
# 					$("#frmSearch" + target + " input").prop("checked", false);
# 					$("#frmSearchSubmit" + target).html("");
# 				}
#
# 				function formSearchSubmit(target) {
# 					$("#frmSearchSubmit" + target).submit();
# 				}
#
# 				$("#frmSearchSide input[type=\'checkbox\']").on("change", function() {
# 					fromSearchSet("Side");
# 				});
#
# 				$("#frmSearchGlobal input[type=\'checkbox\']").on("change", function() {
# 					fromSearchSet("Global");
# 				});
#
# 				function fromSearchSet(target) {
# 					var keyword = Array();
# 					var industries = Array();
# 					var purpose = Array();
# 					var contents = Array();
#
# 					var temp = "";
#
# 					var target_form = "#frmSearch" + target;
# 					var target_submit_form = "#frmSearchSubmit" + target;
#
# 					$(target_submit_form).html("");
# 					$(target_form + " input[type=\'checkbox\']").each(function(i, v) {
# 						var name = $(v).attr("name");
# 						var id = $(v).val();
# 						if($(v).prop("checked")) {
# 							switch(name) {
# 								case "keyword[]":
# 									keyword.push(id);
# 								break;
# 								case "industries[]":
# 									industries.push(id);
# 								break;
# 								case "purpose[]":
# 									purpose.push(id);
# 								break;
# 								case "contents[]":
# 									contents.push(id);
# 								break;
# 							}
# 						}
# 					});
# 					if(keyword.length) {
# 						temp = keyword.toString();
# 						temp = temp.replaceAll(","," ")
# 						$("<input>").attr({
# 							type: "hidden",
# 							name: "keyword",
# 							value: temp
# 						}).appendTo(target_submit_form);
# 					}
# 					if(industries.length) {
# 						temp = industries.toString();
# 						temp = temp.replaceAll(","," ")
# 						$("<input>").attr({
# 							type: "hidden",
# 							name: "industries",
# 							value: temp
# 						}).appendTo(target_submit_form);
# 					}
# 					if(purpose.length) {
# 						temp = purpose.toString();
# 						temp = temp.replaceAll(","," ")
# 						$("<input>").attr({
# 							type: "hidden",
# 							name: "purpose",
# 							value: temp
# 						}).appendTo(target_submit_form);
# 					}
# 					if(contents.length) {
# 						temp = contents.toString();
# 						temp = temp.replaceAll(","," ")
# 						$("<input>").attr({
# 							type: "hidden",
# 							name: "contents",
# 							value: temp
# 						}).appendTo(target_submit_form);
# 					}
#
# 				}
#
# 			});
# 		</script>
# </body>
# </html>

# %%
print(parse_html.title)
# Out:
# <title>シンプレクス株式会社 | Biz×TechでDXを支援</title>

# %%
print(parse_html.title.string)
# Out:
# シンプレクス株式会社 | Biz×TechでDXを支援

# %%
print(parse_html.find_all('a'))
# Out:
# [<a href="/">
# 								シンプレクス株式会社
# 							</a>, <a class="underlink" href="https://www.simplex.ne.jp/en/">
# 									English
# 								</a>, <a class="nav__labeltext" href="/reason/">
# 											選ばれる理由
# 											<span class="nav__arrow"></span>
# </a>, <a class="linebutton" href="/service/finance/">
# <span class="linebutton__label">
# 																	金融サービス開発
# 																</span>
# </a>, <a class="linebutton" href="/service/ui-ux-design/">
# <span class="linebutton__label">
# 																	UI/UXデザイン
# 																</span>
# </a>, <a class="linebutton" href="/service/cloud/">
# <span class="linebutton__label">
# 																	クラウド
# 																</span>
# </a>, <a class="linebutton" href="/service/consulting/">
# <span class="linebutton__label">
# 																	コンサルティング
# 																</span>
# </a>, <a class="linebutton" href="/service/ai/">
# <span class="linebutton__label">
# 																	AI（人工知能）
# 																</span>
# </a>, <a class="linebutton" href="/service/blockchain/">
# <span class="linebutton__label">
# 																	ブロックチェーン
# 																</span>
# </a>, <a class="button" href="/solution/">
# <span class="button__label">
# 																	 ソリューション一覧
# 																</span>
# </a>, <a class="linebutton" href="/industries/bank/">
# <span class="linebutton__label">
# 																	銀行
# 																</span>
# </a>, <a class="linebutton" href="/industries/securities_wholesale/">
# <span class="linebutton__label">
# 																	証券
# 																</span>
# </a>, <a class="linebutton" href="/industries/insurance/">
# <span class="linebutton__label">
# 																	保険
# 																</span>
# </a>, <a class="linebutton" href="/industries/fx/">
# <span class="linebutton__label">
# 																	FX
# 																</span>
# </a>, <a class="linebutton" href="/industries/cryptocurrency/">
# <span class="linebutton__label">
# 																	暗号資産
# 																</span>
# </a>, <a class="linebutton" href="/industries/construction/">
# <span class="linebutton__label">
# 																	建設
# 																</span>
# </a>, <a class="linebutton" href="/industries/public/">
# <span class="linebutton__label">
# 																	公共
# 																</span>
# </a>, <a class="linebutton" href="/industries/manufacture/">
# <span class="linebutton__label">
# 																	製造
# 																</span>
# </a>, <a class="linebutton" href="/industries/retail/">
# <span class="linebutton__label">
# 																	小売・流通
# 																</span>
# </a>, <a class="nav__labeltext" href="/solution/">
# 											ソリューション
# 											<span class="nav__arrow"></span>
# </a>, <a class="nav__labeltext" href="/casestudy/">
# 											事例紹介
# 											<span class="nav__arrow"></span>
# </a>, <a class="nav__labeltext" href="/company/">
# 											企業情報
# 											<span class="nav__door"></span>
# </a>, <a class="linebutton" href="/company/message/">
# <span class="linebutton__label">
# 																	トップメッセージ
# 																</span>
# </a>, <a class="linebutton" href="/company/philosophy/">
# <span class="linebutton__label">
# 																	経営理念
# 																</span>
# </a>, <a class="linebutton" href="/company/about/">
# <span class="linebutton__label">
# 																	会社概要
# 																</span>
# </a>, <a class="linebutton" href="/company/history/">
# <span class="linebutton__label">
# 																	沿革
# 																</span>
# </a>, <a class="linebutton" href="/company/executives/">
# <span class="linebutton__label">
# 																	経営メンバー
# 																</span>
# </a>, <a class="linebutton" href="/company/client/">
# <span class="linebutton__label">
# 																	主要取引先
# 																</span>
# </a>, <a class="linebutton" href="https://www.simplex.holdings/company/finance/" target="_blank">
# <span class="linebutton__label">
# 																	業績・財務情報
# 																</span>
# </a>, <a class="nav__labeltext" href="/news/">
# 											ニュース
# 											<span class="nav__arrow"></span>
# </a>, <a class="nav__labeltext" href="https://recruit-simplex.jp/" rel="noopener" target="_blank">
# 											採用情報
# 											<span class="nav__arrow"></span>
# </a>, <a class="nav__labeltext" href="/contact/">
# 											お問い合わせ
# 											<span class="nav__arrow"></span>
# </a>, <a href="/contact/">
# 										お問い合わせ
# 									</a>, <a href="/downloads/">
# 										資料ダウンロード
# 									</a>, <a href="https://www.simplex.ne.jp/en/">
# 										English
# 									</a>, <a class="button" href="/reason/">
# <span class="button__label">
# 													シンプレクスが選ばれる理由
# 												</span>
# </a>, <a href="/capability/finance/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															金融サービス開発
# 														</p>
# <p class="panel__label">
# 															Financial Services Development
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_finance.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													サービスデザインから業務設計、システム開発まで、迅速な金融サービスの立ち上げを支援します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>, <a href="/capability/ui-ux-design/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															UI/UXデザイン
# 														</p>
# <p class="panel__label">
# 															UI/UX Design
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_uiuxdesign.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													ビジネスを深く理解したUI/UXのエキスパートチームが、ユーザー体験を重視したプロダクト開発を支援します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>, <a href="/capability/cloud/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															クラウド
# 														</p>
# <p class="panel__label">
# 															Cloud
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_cloud.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													先進事例からしか得られない揺るぎない知見を活かし、ビジネス戦略に則したクラウド導入を支援します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>, <a href="/capability/consulting/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															コンサルティング
# 														</p>
# <p class="panel__label">
# 															Consulting
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_consulting.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													最先端テクノロジーに立脚した戦略立案と実行支援により、あらゆる業界のDX推進を支援します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>, <a href="/capability/ai/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															AI（人工知能）
# 														</p>
# <p class="panel__label">
# 															Artificial Intelligence
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_ai.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													戦略策定からビジネス実装まで、あらゆるニーズに即戦力として応えるAIソリューションを提供します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>, <a href="/capability/blockchain/">
# <div class="panel__header">
# <div class="panel__title">
# <p class="panel__subject">
# 															ブロックチェーン
# 														</p>
# <p class="panel__label">
# 															Blockchain
# 														</p>
# </div>
# <figure class="panel__icon">
# <img alt="" height="120" src="/assets/img/common/capability_icon_blockchain.svg" width="120"/>
# </figure>
# </div>
# <p class="panel__summary">
# 													金融領域で培ったブロックチェーン技術と実績をもとに、新たなビジネスをお客様と共創します。
# 												</p>
# <div class="panel__morebutton">
# <span class="morebutton">
# <span class="morebutton__label">
# 															View More
# 														</span>
# </span>
# </div>
# </a>, <a class="linebutton" href="/industries/bank/">
# <span class="linebutton__label">
# 												銀行
# 											</span>
# </a>, <a class="linebutton" href="/industries/construction/">
# <span class="linebutton__label">
# 											建設
# 											</span>
# </a>, <a class="linebutton" href="/industries/securities_wholesale/">
# <span class="linebutton__label">
# 												証券
# 											</span>
# </a>, <a class="linebutton" href="/industries/public/">
# <span class="linebutton__label">
# 												公共
# 											</span>
# </a>, <a class="linebutton" href="/industries/insurance/">
# <span class="linebutton__label">
# 												保険
# 											</span>
# </a>, <a class="linebutton" href="/industries/manufacture/">
# <span class="linebutton__label">
# 												製造
# 											</span>
# </a>, <a class="linebutton" href="/industries/fx/">
# <span class="linebutton__label">
# 												FX
# 											</span>
# </a>, <a class="linebutton" href="/industries/retail/">
# <span class="linebutton__label">
# 												小売・流通
# 											</span>
# </a>, <a class="linebutton" href="/industries/cryptocurrency/">
# <span class="linebutton__label">
# 												暗号資産
# 											</span>
# </a>, <a class="linker" href="https://www.simplex.inc/news/2021/971/" target="_self">
# 														コーポレートサイトリニューアルのお知らせ
# 													</a>, <a class="linker" href="https://www.simplex.inc/news/2021/969/" target="_self">
# 														松井証券の「ネットストック・ハイスピード」のサーバ基盤をAWS上に構築
# 													</a>, <a class="linker" href="https://www.simplex.inc/news/2021/890/" target="_self">
# 														AWSの「2021 APN AWS Top Engineers」に当社プリンシパルが選出
# 													</a>, <a class="linker" href="https://www.simplex.inc/news/2021/837/" target="_self">
# 														シンプレクス、新スマホアプリ「松井証券 株アプリ」を構築
# 													</a>, <a class="linker" href="https://www.simplex.inc/news/2021/557/" target="_self">
# 														DXを支援する「総合コンサルティングファーム」を創設［シンプレクスHD］
# 													</a>, <a class="button" href="/news/">
# <span class="button__label">
# 												ニュース一覧
# 											</span>
# </a>, <a class="button" href="/contact/">
# <span class="button__label">
# 											お問い合わせ
# 										</span>
# </a>, <a class="button" href="/downloads/">
# <span class="button__label">
# 											資料ダウンロード
# 										</span>
# </a>, <a href="/">
# 						シンプレクス株式会社
# 					</a>, <a href="/">
# 										シンプレクス株式会社
# 									</a>, <a href="/service/finance/">
# 													金融サービス開発
# 												</a>, <a href="/service/ui-ux-design/">
# 													UI/UXデザイン
# 												</a>, <a href="/service/cloud/">
# 													クラウド
# 												</a>, <a href="/service/consulting/">
# 													コンサルティング
# 												</a>, <a href="/service/ai/">
# 													AI（人工知能）
# 												</a>, <a href="/service/blockchain/">
# 													ブロックチェーン
# 												</a>, <a href="/industries/bank/">
# 													銀行
# 												</a>, <a href="/industries/securities_wholesale/">
# 													証券
# 												</a>, <a href="/industries/insurance/">
# 													保険
# 												</a>, <a href="/industries/fx/">
# 													FX
# 												</a>, <a href="/industries/cryptocurrency/">
# 													暗号資産
# 												</a>, <a href="/industries/construction/">
# 													建設
# 												</a>, <a href="/industries/public/">
# 													公共
# 												</a>, <a href="/industries/manufacture/">
# 													製造
# 												</a>, <a href="/industries/retail/">
# 													小売・流通
# 												</a>, <a class="sitemap__label" href="/reason/">
# 												選ばれる理由
# 											</a>, <a class="sitemap__label" href="/solution/">
# 												ソリューション一覧
# 											</a>, <a class="sitemap__label" href="/casestudy/">
# 												事例紹介
# 											</a>, <a class="sitemap__label" href="/company/">
# 												企業情報
# 											</a>, <a href="/company/message/">
# 													トップメッセージ
# 												</a>, <a href="/company/philosophy/">
# 													経営理念
# 												</a>, <a href="/company/about/">
# 													会社概要
# 												</a>, <a href="/company/history/">
# 													沿革
# 												</a>, <a href="/company/executives/">
# 													経営メンバー
# 												</a>, <a href="/company/client/">
# 													主要取引先
# 												</a>, <a href="https://www.simplex.holdings/company/finance/" target="_blank">
# 													業績・財務情報
# 												</a>, <a class="sitemap__label" href="/news/">
# 												ニュース
# 											</a>, <a class="sitemap__label" href="https://recruit-simplex.jp/" rel="noopener" target="_blank">
# 												採用情報
# 											</a>, <a class="sitemap__label" href="/downloads/">
# 												資料ダウンロード
# 											</a>, <a class="sitemap__label" href="/contact/">
# 												お問い合わせ
# 											</a>, <a href="/term/">
# 										サイトポリシー
# 									</a>, <a href="/security/">
# 										情報セキュリティ基本方針
# 									</a>, <a href="/privacy/">
# 										個人情報保護方針
# 									</a>, <a href="/sitemap/">
# 										サイトマップ
# 									</a>, <a href="https://www.simplex.holdings/notification/" target="_blank">
# 										電子公告
# 									</a>]

# %%
title_lists = parse_html.find_all('a')

# %%
title_lists[0:10]
# Out:
# [<a href="/">
#  								シンプレクス株式会社
#  							</a>,
#  <a class="underlink" href="https://www.simplex.ne.jp/en/">
#  									English
#  								</a>,
#  <a class="nav__labeltext" href="/reason/">
#  											選ばれる理由
#  											<span class="nav__arrow"></span>
#  </a>,
#  <a class="linebutton" href="/service/finance/">
#  <span class="linebutton__label">
#  																	金融サービス開発
#  																</span>
#  </a>,
#  <a class="linebutton" href="/service/ui-ux-design/">
#  <span class="linebutton__label">
#  																	UI/UXデザイン
#  																</span>
#  </a>,
#  <a class="linebutton" href="/service/cloud/">
#  <span class="linebutton__label">
#  																	クラウド
#  																</span>
#  </a>,
#  <a class="linebutton" href="/service/consulting/">
#  <span class="linebutton__label">
#  																	コンサルティング
#  																</span>
#  </a>,
#  <a class="linebutton" href="/service/ai/">
#  <span class="linebutton__label">
#  																	AI（人工知能）
#  																</span>
#  </a>,
#  <a class="linebutton" href="/service/blockchain/">
#  <span class="linebutton__label">
#  																	ブロックチェーン
#  																</span>
#  </a>,
#  <a class="button" href="/solution/">
#  <span class="button__label">
#  																	 ソリューション一覧
#  																</span>
#  </a>]

# %%
title_lists[10].attrs['href']
# Out:
# '/industries/bank/'

# %%
title_list = []
url_list = []

for i in title_lists:
    title_list.append(i.string)
    url_list.append(i.attrs['href'])

# %%
title_list
# Out:
# ['\r\n\t\t\t\t\t\t\t\tシンプレクス株式会社\r\n\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\tEnglish\r\n\t\t\t\t\t\t\t\t',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '\r\n\t\t\t\t\t\t\t\t\t\tお問い合わせ\r\n\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t資料ダウンロード\r\n\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\tEnglish\r\n\t\t\t\t\t\t\t\t\t',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tコーポレートサイトリニューアルのお知らせ\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t松井証券の「ネットストック・ハイスピード」のサーバ基盤をAWS上に構築\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tAWSの「2021 APN AWS Top Engineers」に当社プリンシパルが選出\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tシンプレクス、新スマホアプリ「松井証券 株アプリ」を構築\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tDXを支援する「総合コンサルティングファーム」を創設［シンプレクスHD］\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  None,
#  None,
#  None,
#  '\r\n\t\t\t\t\t\tシンプレクス株式会社\r\n\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\tシンプレクス株式会社\r\n\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t金融サービス開発\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tUI/UXデザイン\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tクラウド\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tコンサルティング\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tAI（人工知能）\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tブロックチェーン\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t銀行\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t証券\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t保険\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tFX\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t暗号資産\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t建設\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t公共\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t製造\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t小売・流通\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t選ばれる理由\r\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\tソリューション一覧\r\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t事例紹介\r\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t企業情報\r\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tトップメッセージ\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t経営理念\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t会社概要\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t沿革\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t経営メンバー\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t主要取引先\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t業績・財務情報\r\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\tニュース\r\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t採用情報\r\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\t資料ダウンロード\r\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t\t\tお問い合わせ\r\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\tサイトポリシー\r\n\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t情報セキュリティ基本方針\r\n\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t個人情報保護方針\r\n\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\tサイトマップ\r\n\t\t\t\t\t\t\t\t\t',
#  '\r\n\t\t\t\t\t\t\t\t\t\t電子公告\r\n\t\t\t\t\t\t\t\t\t']

# %%
url_list
# Out:
# ['/',
#  'https://www.simplex.ne.jp/en/',
#  '/reason/',
#  '/service/finance/',
#  '/service/ui-ux-design/',
#  '/service/cloud/',
#  '/service/consulting/',
#  '/service/ai/',
#  '/service/blockchain/',
#  '/solution/',
#  '/industries/bank/',
#  '/industries/securities_wholesale/',
#  '/industries/insurance/',
#  '/industries/fx/',
#  '/industries/cryptocurrency/',
#  '/industries/construction/',
#  '/industries/public/',
#  '/industries/manufacture/',
#  '/industries/retail/',
#  '/solution/',
#  '/casestudy/',
#  '/company/',
#  '/company/message/',
#  '/company/philosophy/',
#  '/company/about/',
#  '/company/history/',
#  '/company/executives/',
#  '/company/client/',
#  'https://www.simplex.holdings/company/finance/',
#  '/news/',
#  'https://recruit-simplex.jp/',
#  '/contact/',
#  '/contact/',
#  '/downloads/',
#  'https://www.simplex.ne.jp/en/',
#  '/reason/',
#  '/capability/finance/',
#  '/capability/ui-ux-design/',
#  '/capability/cloud/',
#  '/capability/consulting/',
#  '/capability/ai/',
#  '/capability/blockchain/',
#  '/industries/bank/',
#  '/industries/construction/',
#  '/industries/securities_wholesale/',
#  '/industries/public/',
#  '/industries/insurance/',
#  '/industries/manufacture/',
#  '/industries/fx/',
#  '/industries/retail/',
#  '/industries/cryptocurrency/',
#  'https://www.simplex.inc/news/2021/971/',
#  'https://www.simplex.inc/news/2021/969/',
#  'https://www.simplex.inc/news/2021/890/',
#  'https://www.simplex.inc/news/2021/837/',
#  'https://www.simplex.inc/news/2021/557/',
#  '/news/',
#  '/contact/',
#  '/downloads/',
#  '/',
#  '/',
#  '/service/finance/',
#  '/service/ui-ux-design/',
#  '/service/cloud/',
#  '/service/consulting/',
#  '/service/ai/',
#  '/service/blockchain/',
#  '/industries/bank/',
#  '/industries/securities_wholesale/',
#  '/industries/insurance/',
#  '/industries/fx/',
#  '/industries/cryptocurrency/',
#  '/industries/construction/',
#  '/industries/public/',
#  '/industries/manufacture/',
#  '/industries/retail/',
#  '/reason/',
#  '/solution/',
#  '/casestudy/',
#  '/company/',
#  '/company/message/',
#  '/company/philosophy/',
#  '/company/about/',
#  '/company/history/',
#  '/company/executives/',
#  '/company/client/',
#  'https://www.simplex.holdings/company/finance/',
#  '/news/',
#  'https://recruit-simplex.jp/',
#  '/downloads/',
#  '/contact/',
#  '/term/',
#  '/security/',
#  '/privacy/',
#  '/sitemap/',
#  'https://www.simplex.holdings/notification/']
